# %%
import openai

# %%
# read the data/combined_transcript.txt file into a string variable
with open("data/combined_transcript.txt", "r") as f:
    transcript = f.read()

# %%
from dotenv import load_dotenv

load_dotenv()

from openai import OpenAI

openai = OpenAI()

response = openai.chat.completions.create(
    model='openai.gpt-4o-mini',
    messages=[
        {'role': 'system', 'content': 'You are a helpful assistant.'},
        {'role': 'user', 'content': transcript},
    ],
).choices[0].message.content

print(f'{response}')
# Out:
# It looks like you have provided a detailed transcript of a classroom session focused on artificial intelligence, specifically discussing tools like Gemini, AI functionalities, and the implications of using AI in practical applications. The conversation covers various topics, including the inner critic in AI, using AI to aid in work projects, ethical considerations, AI-generated content, and technical aspects of AI models and APIs.
#
# If you have specific questions or topics you would like me to help with regarding AI, its applications, or anything mentioned in the transcript, feel free to let me know!
